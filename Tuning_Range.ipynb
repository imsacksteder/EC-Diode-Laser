# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as p
from scipy.stats import stats
from scipy.optimize import curve_fit
import scipy.optimize

# %%
up = p.read_csv('upper_bound.csv')
#plt.plot(up.Wavelength[1800:1950], up.IntensityFactor[1800:1950])
#plt.show()

# %%
low = p.read_csv('lower_bound.csv')
#plt.plot(low.Wavelength[1900:2100], low.IntensityFactor[1900:2100])
#plt.show()

# %%
plt.plot(up.Wavelength[1800:2050], up.IntensityFactor[1800:2050],'r', label='Upper bound')
plt.plot(low.Wavelength[1800:2050], low.IntensityFactor[1800:2050],'b', label='Lower bound')

plt.legend(loc='upper left')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Intensity Factor (??)')
plt.title('Intensity Factor versus Wavelength')
# Out:
# Text(0.5, 1.0, 'Intensity Factor versus Wavelength')
